# %%
import networkx as nx

# %%
g = nx.read_gpickle('python2_readable_pickle.pickle')

# %%
not_canonical = [n[0] for n in G.nodes(data=True) if 'yob' not in n[1] or if 'yob' in n[1] and n[1]['yob'] < 1910]
canonical = [n[0] for n ]
# Out:
# [(u'point v', {u'degree': 1, u'in_degree': 1, u'out_degree': 0}),
#  (u'gawlik e', {u'degree': 1, u'in_degree': 1, u'out_degree': 0}),
#  (u'rashed r', {u'degree': 2, u'in_degree': 2, u'out_degree': 0}),
#  (u'ljubisavljevic m', {u'degree': 1, u'in_degree': 1, u'out_degree': 0}),
#  (u'booth a r', {u'degree': 80, u'in_degree': 3, u'out_degree': 77}),
#  (u'ruijsenaars s', {u'degree': 2, u'in_degree': 2, u'out_degree': 0}),
#  (u'woods', {u'degree': 3, u'in_degree': 3, u'out_degree': 0}),
#  (u'hoffman s j', {u'degree': 2, u'in_degree': 2, u'out_degree': 0}),
#  (u'rashed m', {u'degree': 1, u'in_degree': 1, u'out_degree': 0}),
#  (u'kurtz k j', {u'degree': 1, u'in_degree': 1, u'out_degree': 0}),
#  (u'budolfson m', {u'degree': 2, u'in_degree': 2, u'out_degree': 0}),
#  (u'lhopital g', {u'degree': 1, u'in_degree': 1, u'out_degree': 0}),
#  (u'caney', {u'degree': 1, u'in_degree': 1, u'out_degree': 0}),
#  (u'medin d l', {u'degree': 15, u'in_degree': 15, u'out_degree': 0}),
# ...
